# %% [markdown]
# # Twitter Analysis

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from random import randint
import matplotlib.pyplot as plt

# %%
user = pd.read_excel("Output/Twitter.xlsx")
tweets = pd.read_excel("Output/Twitter.xlsx",sheet_name="Tweets")

# %%
user.head()
# Out:
#   User Name User Handle                                                Bio  \
# 0   Twitter     Twitter                                 What's happening?!
# 1   YouTube     YouTube                                like and subscribe.
# 2      Meta        Meta  Meta is helping build a future where people ha...
# 3  Snapchat    Snapchat  Say it with a Lens. #OpenYourSnapchat\n\nNeed ...
# 4  WhatsApp    WhatsApp                          Simple. Secure. Reliable.
#
#            Created At  Followers  Following  Account Age  Average Tweets  \
# 0 2007-02-20 14:35:54   60949258          5         5487            2.73
# 1 2007-11-13 21:43:46   74473165       1207         5220            8.21
# 2 2007-03-27 07:29:25   13902876        722         5452            2.84
# 3 2011-09-20 00:35:44    2328557         21         3814            1.97
# 4 2009-05-15 02:01:15    4074918          0         4672            0.44
#
#                                               Tweets  \
# 0  ['https://t.co/824UoJmqtx', 'we asked the engi...
# 1  [".@JaleesaJaikaran's makeup looks *literally*...
# 2  ["@Thisishowispeak Let 'em know! Can't wait to...
# 3  ["Who's up for a Snap Map food tour? 🍴 https:/...
# 4  ['For more information on our efforts to keep ...
#
#                                       Tweets Created
# 0  [datetime.datetime(2022, 2, 17, 22, 20, 46), d...
# 1  [datetime.datetime(2022, 2, 24, 2, 0, 9), date...
# 2  [datetime.datetime(2022, 2, 25, 21, 37, 18), d...
# 3  [datetime.datetime(2022, 2, 24, 22, 50, 32), d...
# 4  [datetime.datetime(2022, 2, 27, 17, 25, 24), d...

# %%
tweets.head()
# Out:
#                                              Twitter Twitter Tweet Timestamp  \
# 0                            https://t.co/824UoJmqtx     2022-02-17 22:20:46
# 1  we asked the engineers if we could pin a DM an...     2022-02-17 19:01:44
# 2  @EmojiMashupBot thank you, you're one of the #...     2022-02-16 20:27:27
# 3                                laughing but crying     2022-02-16 20:09:57
# 4  @SourPatchKids 10,000 Sour Patch Watermelons. ...     2022-02-14 01:42:59
#
#                                              YouTube YouTube Tweet Timestamp  \
# 0  .@JaleesaJaikaran's makeup looks *literally* t...     2022-02-24 02:00:09
# 1  @FaxRBX i have a feeling you'd be good at Wher...     2022-02-24 01:52:57
# 2            @r41ningpuppies Nothing gets past you 💸     2022-02-24 01:49:11
# 3  @donaldave20051 you've got a keen eye for emoj...     2022-02-24 01:47:11
# 4                 @Soentken now that sounds lovely 😌     2022-02-24 01:44:50
#
#                                                 Meta Meta Tweet Timestamp  \
# 0  @Thisishowispeak Let 'em know! Can't wait to s...  2022-02-25 21:37:18
# 1  @Armandorsn Our guided help tool can walk you ...  2022-02-25 18:36:35
# 2  @BajrangdalG Please visit this link and follow...  2022-02-25 18:36:17
# 3  @temo_zedginidze Here are some things that you...  2022-02-25 18:36:03
# 4  @susancurran1970 Thank you for the feedback! Y...  2022-02-25 09:22:24
#
#                                             Snapchat Snapchat Tweet Timestamp  \
# 0  Who's up for a Snap Map food tour? 🍴 https://t...      2022-02-24 22:50:32
# 1    Never miss an episode 📺 https://t.co/9QcNoup1Au      2022-02-24 17:30:27
# 2                      🙌 🙌 🙌 https://t.co/VbF9svTF73      2022-02-24 00:30:50
# 3  Talen rocks. He also acts. And he wants to sho...      2022-02-24 00:00:01
# 4              No pressure 😊 https://t.co/LhLRvgxogk      2022-02-23 22:45:01
#
#                                             WhatsApp WhatsApp Tweet Timestamp  \
# 0  For more information on our efforts to keep pe...      2022-02-27 17:25:24
# 1  As a reminder, we have limits on message forwa...      2022-02-27 17:25:24
# 2  You can also turn on fingerprint lock. When th...      2022-02-27 17:25:24
# 3  We strongly recommend everyone enable two-step...      2022-02-27 17:25:24
# 4  In addition, Disappearing Mode automatically e...      2022-02-27 17:25:24
#
#    ...                                            TRILLER  \
# 0  ...  Where is your favorite place to meditate? ☮️\n...
# 1  ...  “Anxiety is the misuse of imagination” -@Deepa...
# 2  ...  We have this one on 🔁 have you guys heard @Tin...
# 3  ...  Naturally out now on Triller! @Tinashe #NewMus...
# 4  ...  West London artist, @hope_tala is dropping hit...
#
#   TRILLER Tweet Timestamp                                         Houseparty  \
# 0     2022-02-26 04:22:46                                   @RayandolfoYT ❤️
# 1     2022-02-26 00:12:02  @Mz_louisiana28 We’re so lucky to have had so ...
# 2     2022-02-25 23:46:23  @TheGr3atTP There are a ton of group video app...
# 3     2022-02-25 23:05:01                                    @realUNOgame ❤️
# 4     2022-02-25 22:41:05  Millions of people around the world have used ...
#
#   Houseparty Tweet Timestamp  \
# 0        2021-09-09 20:51:54
# 1        2021-09-09 20:51:12
# 2        2021-09-09 20:50:25
# 3        2021-09-09 19:09:39
# 4        2021-09-09 19:02:45
#
#                                             Caffeine Caffeine Tweet Timestamp  \
# 0          @BATTLEFEST @StreetsyB we love to hear it      2022-02-28 00:01:30
# 1  RT @urltv: #URL comes to ATL Sunday March 27th...      2022-02-27 18:46:30
# 2  RT @urltv: CALICOE VS CHESS TRAILER (MARCH 27T...      2022-02-27 18:46:24
# 3  "You never metaverse more ridiculous, its like...      2022-02-27 01:28:58
# 4  RT @UrBoYCLO: Watch #URLResolution with me on ...      2022-02-27 01:09:34
#
#                                               Tinder Tinder Tweet Timestamp  \
# 0  RT @lyft: @Tinder 🚨 NEW FEATURE ALERT 🚨\nSend ...    2022-02-16 01:39:26
# 1     @lyft it’s giving luxury, it’s giving opulence    2022-02-16 01:39:20
# 2              @lyft omg do we make this official? 🙈    2022-02-16 01:36:28
# 3  @lyft this is literally the hottest thing anyo...    2022-02-16 01:34:14
# 4         @lyft it’s a date babes! calling a Lyft rn    2022-02-16 01:32:23
#
#                                               GitHub GitHub Tweet Timestamp
# 0  Using GitHub-hosted Actions? There's a new way...    2022-02-23 21:34:01
# 1  New Changelog with latest feature updates for ...    2022-02-23 19:50:01
# 2  Codespaces for your largest repositories just ...    2022-02-23 18:18:08
# 3  JLess looks like a great way to to view, navig...    2022-02-22 22:22:03
# 4  GitHub Advisory Database now accepts community...    2022-02-22 17:36:10
#
# [5 rows x 42 columns]

# %%
colors = ['Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap',
          'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 
          'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 
          'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 
          'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 
          'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 
          'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 
          'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 
          'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 
          'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 
          'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 
          'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 
          'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spectral', 'nipy_spectral_r', 
          'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 
          'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 
          'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 
          'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r']

# %%
value = randint(0, len(colors)-1)

user_analysis = user.copy()

user_analysis.set_index('User Name',inplace=True,drop=True)
user_analysis.index.name = "Platform"

plt.figure(figsize=(10,3))

plt.suptitle("Oldest vs Youngest Platforms on Twitter")

plt.subplot(1,2,1)
plt.xlabel("Platforms")
plt.ylabel("Age (Years)")
user_analysis['Account Age'].sort_values(ascending=False).head(10).plot(kind='bar',colormap=colors[value])

plt.subplot(1,2,2)
plt.xlabel("Platforms")
plt.ylabel("Age (Years)")
user_analysis['Account Age'].sort_values(ascending=False).tail(10).plot(kind='bar',colormap=colors[value])

plt.tight_layout(pad=1)

# %%
value = randint(0, len(colors)-1)

user_analysis = user.copy()

user_analysis.set_index('User Name',inplace=True,drop=True)
user_analysis.index.name = "Platform"

user_analysis['Following'] = user_analysis['Following'].apply(lambda x: np.log(x))
user_analysis['Followers'] = user_analysis['Followers'].apply(lambda x: np.log(x))

user_analysis[['Followers','Following']].plot(kind='bar',colormap=colors[value])
# Out:
# <AxesSubplot:xlabel='Platform'>
